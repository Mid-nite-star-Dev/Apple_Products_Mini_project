# %%
import pandas as pd   #NB: this is done after installing pandas on your jupyter notebook

# %%
df=pd.read_csv('apple_products.csv') #using df as the name variable to access the csv file named'apple_products.csv' NB: you can use any name as your variable

# %%
df   #showing the total records of rows and columns in the dataset named 'apple_products.csv' which have 62 records NB: the counting starts from 0
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df.head() #shows the first five records of the dataset
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.tail() #shows the last five records of the dataset
# Out:
#                        Product Name  \
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 57  39900                   24              95909               8161
# 58  54900                   14              43470               3331
# 59  54900                   14              43470               3331
# ...

# %%
df.count() #To check/understand if the records of rows and columns content have all complete values before any transformation
# Out:
# Product Name           62
# Product URL            62
# Brand                  62
# Sale Price             62
# Mrp                    62
# Discount Percentage    62
# Number Of Ratings      62
# Number Of Reviews      62
# Upc                    62
# Star Rating            62
# Ram                    62
# dtype: int64

# %%
df.describe()
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# ...

# %%
df['Mrp'].max() #maximum amount of a product
# Out:
# 149900

# %%
df['Mrp'].min() #minimum amount of a product
# Out:
# 39900

# %%
df[df['Mrp']==149900] #products with maximum sales --Mrp
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 24  149900                    6                542                 42
# 41  149900                    6                545                 42
#
#                  Upc  Star Rating   Ram
# 24  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
df[df['Mrp']==39900] #products with minimum sales --Mrp
# Out:
#                       Product Name  \
# 52  APPLE iPhone SE (White, 64 GB)
# 57  APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 52  39900                   24              95807               8154
# 57  39900                   24              95909               8161
#
#                  Upc  Star Rating   Ram
# 52  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 57  MOBFWQ6BR3MK7AUG          4.5  4 GB

# %%
df.sort_values(by=['Star Rating']) #ascending order starting with the least 'Star Rating' NB ascending is by default which shows the least 'Star Rating' first
# Out:
#                                         Product Name  \
# 30            APPLE iPhone 12 Pro (Graphite, 128 GB)
# 38                 APPLE iPhone 12 Mini (Red, 64 GB)
# 28               APPLE iPhone 12 Mini (White, 64 GB)
# 27            APPLE iPhone 12 Pro (Graphite, 256 GB)
# 26              APPLE iPhone 12 Mini (White, 128 GB)
# ..                                               ...
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 30  https://www.flipkart.com/apple-iphone-12-pro-g...  Apple      110900
# 38  https://www.flipkart.com/apple-iphone-12-mini-...  Apple       59900
# 28  https://www.flipkart.com/apple-iphone-12-mini-...  Apple       59900
# ...

# %%
df.sort_values(by=['Star Rating'],ascending=False) #starting with the highest 'Star Rating' NB using a Boolean 'False' to change the ascending by default therefore the highest 'Star Rating' will start first
# Out:
#                                          Product Name  \
# 20    APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17        APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16   APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15              APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14             APPLE iPhone 11 Pro Max (Gold, 256 GB)
# ..                                                ...
# 45                APPLE iPhone 12 Mini (Black, 64 GB)
# 28                APPLE iPhone 12 Mini (White, 64 GB)
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 41         APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 27             APPLE iPhone 12 Pro (Graphite, 256 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# ...

# %%
type(df['Product Name'])
# Out:
# pandas.core.series.Series

# %%
#
listed_col=list(df['Product Name'])

# %%
listed_col
# Out:
# ['APPLE iPhone 8 Plus (Gold, 64 GB)',
#  'APPLE iPhone 8 Plus (Space Grey, 256 GB)',
#  'APPLE iPhone 8 Plus (Silver, 256 GB)',
#  'APPLE iPhone 8 (Silver, 256 GB)',
#  'APPLE iPhone 8 (Gold, 256 GB)',
#  'APPLE iPhone 8 Plus (Silver, 64 GB)',
#  'APPLE iPhone 8 Plus (Space Grey, 64 GB)',
#  'APPLE iPhone 8 (Space Grey, 256 GB)',
#  'APPLE iPhone XS Max (Silver, 64 GB)',
#  'Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)',
#  'Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)',
#  'Apple iPhone XR (Coral, 128 GB) (Includes EarPods, Power Adapter)',
#  'Apple iPhone XR (Black, 128 GB) (Includes EarPods, Power Adapter)',
#  'Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)',
#  'APPLE iPhone 11 Pro Max (Gold, 256 GB)',
#  'APPLE iPhone 11 Pro Max (Gold, 64 GB)',
#  'APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)',
#  'APPLE iPhone 11 Pro Max (Space Grey, 64 GB)',
#  'APPLE iPhone 11 Pro (Midnight Green, 64 GB)',
# ...

# %%
listed_col=df['Product Name']

# %%
#using the index and slicing the string of the 'Product Name' 
listed_col[1][6:15]
# Out:
# 'iPhone 8 '

# %%
#strip function helps remove any spaces from both sides of the index string
listed_col[1][6:15].strip()
# Out:
# 'iPhone 8'

# %%
type(listed_col[1][6:15].strip())
# Out:
# str

# %%
#adding a new colunm name 'Model Name'
df['Model Name']=df['Product Name'].str[6:15]

# %%
df #The new resulting DataFrame with a new unique colunm 'Model Name' to represent the 'Product Name'
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...
